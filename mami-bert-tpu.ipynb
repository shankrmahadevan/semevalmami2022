# %%
# from tensorflow.keras import mixed_precision
# # On TPUs, use 'mixed_bfloat16' instead
# mixed_precision.set_global_policy('mixed_bfloat16')

# %%
from kaggle_datasets import KaggleDatasets
GCS_DS_PATH = KaggleDatasets().get_gcs_path()

# %%
from transformers import BertTokenizer, TFBertModel
import tensorflow as tf
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
print("Device:", tpu.master())
strategy = tf.distribute.TPUStrategy(tpu)
print("Number of replicas:", strategy.num_replicas_in_sync)
# Out:
# 2022-01-27 09:02:05.066784: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-01-27 09:02:05.066856: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30181}
# 2022-01-27 09:02:05.069355: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job worker -> {0 -> 10.0.0.2:8470}
# 2022-01-27 09:02:05.069408: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:301] Initialize GrpcChannelCache for job localhost -> {0 -> localhost:30181}
# Device: grpc://10.0.0.2:8470
# Number of replicas: 8

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
user_credential = user_secrets.get_gcloud_credential()
user_secrets.set_tensorflow_credential(user_credential)

# %%
def create_model(maxlen=512):
    text_model = TFBertModel.from_pretrained("bert-base-uncased")
    image_model = tf.keras.applications.efficientnet.EfficientNetB5(
          include_top=False,
          input_shape=(299, 299, 3)
    )
    for layer in image_model.layers[:-25]:
        layer.trainable = False
    x = tf.keras.layers.GlobalAveragePooling2D()(image_model.output)
    x = tf.keras.layers.Dense(2048,activation='relu')(x) # Best model has this
  
    input_ids = tf.keras.Input(shape=(maxlen,),dtype='int32', name='input_text')
    sequence_output = text_model(input_ids)[0]
    cls_token = sequence_output[:, 0, :]
    cls_token = tf.keras.layers.Dense(2048,activation='relu')(cls_token) # Best model has this
  
    concat_layer = tf.keras.layers.Concatenate()([x, cls_token])
  
    output = tf.keras.layers.Dense(512,activation='relu')(concat_layer)
    output = tf.keras.layers.Dropout(0.2)(output) # Best model has this
    binary_output = tf.keras.layers.Dense(1,activation='sigmoid', name='misogynous')(output)
    multi_label_output = tf.keras.layers.Dense(512,activation='relu')(output) # Best model has this
    a = tf.keras.layers.Dense(1,activation='sigmoid', name='a')(multi_label_output) # Best model has this
    b = tf.keras.layers.Dense(128,activation='relu')(multi_label_output) # Best model has this
    b = tf.keras.layers.Dense(1,activation='sigmoid', name='b')(b) # Best model has this
    c = tf.keras.layers.Dense(1,activation='sigmoid', name='c')(multi_label_output) # Best model has this
    d = tf.keras.layers.Dense(1,activation='sigmoid', name='d')(multi_label_output) # Best model has this
    model = tf.keras.models.Model(inputs = [image_model.input, input_ids], outputs=[binary_output, a, b, c, d])
    model.compile(tf.keras.optimizers.Adam(learning_rate=6e-5), loss={'misogynous': 'binary_crossentropy', 'a': 'binary_crossentropy', 'b': 'binary_crossentropy', 'c': 'binary_crossentropy', 'd': 'binary_crossentropy'}, metrics=['accuracy'])
    return model

# %%
with strategy.scope():
    model = create_model()
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
import collections

def parse_records(example_proto):
  feature_description = {
    'image': tf.io.FixedLenFeature([], tf.string),
    'text':  tf.io.VarLenFeature(tf.int64),
    'label': tf.io.FixedLenFeature([], tf.int64),
    'multi_label': tf.io.VarLenFeature(tf.int64),
  }
  example = tf.io.parse_single_example(example_proto, feature_description)
  example['image'] = tf.io.decode_jpeg(example['image'], channels=3)
  example['multi_label'] = example['multi_label'].values
  example['text'] = example['text'].values
  return example

def prepare_sample(features):
    image = tf.image.resize(features["image"], size=(299, 299))
    text = features["text"]
    label = features['label']
    multi_label = features['multi_label']
    return collections.OrderedDict(input_1=image, input_text=text), collections.OrderedDict(misogynous=label, a=multi_label[0], b=multi_label[1], c=multi_label[2], d=multi_label[3],)
#     return collections.OrderedDict(input_1=image, input_text=text), collections.OrderedDict(multi_label=multi_label)

def get_dataset(filenames, batch_size, mode='train'):
    
    ignore_order = tf.data.Options()
    ignore_order.experimental_deterministic = False
    dataset = (
        tf.data.TFRecordDataset(filenames, num_parallel_reads=AUTOTUNE)
        .with_options(ignore_order)
        .map(parse_records, num_parallel_calls=AUTOTUNE)
        .map(prepare_sample, num_parallel_calls=AUTOTUNE)
        .shuffle(batch_size * 10)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
    )
    if mode=='train':
        dataset = dataset.repeat()
    return dataset

# %%
from glob import glob
train_data = tf.io.gfile.glob(f'{GCS_DS_PATH}/train/content/MAMI_BERT/train/*.tfrecords') + tf.io.gfile.glob(f'{GCS_DS_PATH}/eval/*.tfrecords')
eval_data = [train_data[0]]
train_data = train_data[1:]
batch_size = 256
AUTOTUNE = tf.data.AUTOTUNE

# %%
train_dataset = get_dataset(train_data, batch_size)
eval_dataset = get_dataset(eval_data, batch_size, mode='eval')

# %%
early_stopping_cb = tf.keras.callbacks.EarlyStopping(
#     patience=10, restore_best_weights=True, monitor='val_multi_label_loss'
        patience=10, restore_best_weights=True, monitor='val_misogynous_accuracy'
)
class PolynomialDecay():
    def __init__(self, maxEpochs=100, initAlpha=0.01, power=1.0):
        self.maxEpochs = maxEpochs
        self.initAlpha = initAlpha
        self.power = power
    def __call__(self, epoch):
        decay = (1 - (epoch / float(self.maxEpochs))) ** self.power
        alpha = self.initAlpha * decay
        return float(alpha)
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(PolynomialDecay(initAlpha=6e-5))

# %%
model.fit(train_dataset, steps_per_epoch=10000//batch_size, epochs=50, validation_data=eval_dataset, callbacks=[early_stopping_cb, lr_scheduler])
# Out:
# Epoch 1/50
# 39/39 [==============================] - 220s 2s/step - loss: 2.6678 - misogynous_loss: 0.6611 - a_loss: 0.4157 - b_loss: 0.6182 - c_loss: 0.5349 - d_loss: 0.4380 - misogynous_accuracy: 0.5903 - a_accuracy: 0.8667 - b_accuracy: 0.6908 - c_accuracy: 0.7401 - d_accuracy: 0.8023 - val_loss: 2.2144 - val_misogynous_loss: 0.5825 - val_a_loss: 0.3308 - val_b_loss: 0.5834 - val_c_loss: 0.4250 - val_d_loss: 0.2927 - val_misogynous_accuracy: 0.6680 - val_a_accuracy: 0.8820 - val_b_accuracy: 0.7120 - val_c_accuracy: 0.8280 - val_d_accuracy: 0.9140
# 2022-01-27 09:06:48.579035: W ./tensorflow/core/distributed_runtime/eager/destroy_tensor_handle_node.h:57] Ignoring an error encountered when deleting remote tensors handles: Invalid argument: Unable to find the relevant tensor remote_handle: Op ID: 70464, Output num: 8
# Additional GRPC error information from remote target /job:worker/replica:0/task:0:
# :{"created":"@1643274408.575545860","description":"Error received from peer ipv4:10.0.0.2:8470","file":"external/com_github_grpc_grpc/src/core/lib/surface/call.cc","file_line":1056,"grpc_message":"Unable to find the relevant tensor remote_handle: Op ID: 70464, Output num: 8","grpc_status":3}
# Epoch 2/50
# 39/39 [==============================] - 46s 1s/step - loss: 2.2446 - misogynous_loss: 0.5564 - a_loss: 0.3441 - b_loss: 0.5839 - c_loss: 0.4294 - d_loss: 0.3309 - misogynous_accuracy: 0.7066 - a_accuracy: 0.8676 - b_accuracy: 0.7060 - c_accuracy: 0.8308 - d_accuracy: 0.8933 - val_loss: 2.1254 - val_misogynous_loss: 0.5443 - val_a_loss: 0.3192 - val_b_loss: 0.5677 - val_c_loss: 0.4081 - val_d_loss: 0.2860 - val_misogynous_accuracy: 0.7080 - val_a_accuracy: 0.8820 - val_b_accuracy: 0.7320 - val_c_accuracy: 0.8300 - val_d_accuracy: 0.9140
# Epoch 3/50
# 39/39 [==============================] - 47s 1s/step - loss: 2.1567 - misogynous_loss: 0.5240 - a_loss: 0.3409 - b_loss: 0.5653 - c_loss: 0.4135 - d_loss: 0.3130 - misogynous_accuracy: 0.7361 - a_accuracy: 0.8636 - b_accuracy: 0.7094 - c_accuracy: 0.8298 - d_accuracy: 0.8958 - val_loss: 2.1470 - val_misogynous_loss: 0.5322 - val_a_loss: 0.3236 - val_b_loss: 0.5944 - val_c_loss: 0.4035 - val_d_loss: 0.2933 - val_misogynous_accuracy: 0.7120 - val_a_accuracy: 0.8820 - val_b_accuracy: 0.7300 - val_c_accuracy: 0.8360 - val_d_accuracy: 0.9140
# Epoch 4/50
# 39/39 [==============================] - 47s 1s/step - loss: 2.0307 - misogynous_loss: 0.4956 - a_loss: 0.3158 - b_loss: 0.5438 - c_loss: 0.3846 - d_loss: 0.2909 - misogynous_accuracy: 0.7571 - a_accuracy: 0.8699 - b_accuracy: 0.7275 - c_accuracy: 0.8429 - d_accuracy: 0.9037 - val_loss: 2.1035 - val_misogynous_loss: 0.5198 - val_a_loss: 0.3116 - val_b_loss: 0.5852 - val_c_loss: 0.3986 - val_d_loss: 0.2884 - val_misogynous_accuracy: 0.7440 - val_a_accuracy: 0.8820 - val_b_accuracy: 0.7060 - val_c_accuracy: 0.8360 - val_d_accuracy: 0.9140
# Epoch 5/50
# 39/39 [==============================] - 47s 1s/step - loss: 1.9517 - misogynous_loss: 0.4683 - a_loss: 0.2983 - b_loss: 0.5302 - c_loss: 0.3777 - d_loss: 0.2772 - misogynous_accuracy: 0.7739 - a_accuracy: 0.8774 - b_accuracy: 0.7348 - c_accuracy: 0.8449 - d_accuracy: 0.9042 - val_loss: 1.9495 - val_misogynous_loss: 0.4419 - val_a_loss: 0.3196 - val_b_loss: 0.5207 - val_c_loss: 0.3936 - val_d_loss: 0.2737 - val_misogynous_accuracy: 0.7940 - val_a_accuracy: 0.8900 - val_b_accuracy: 0.6980 - val_c_accuracy: 0.8380 - val_d_accuracy: 0.9160
# Epoch 6/50
# 39/39 [==============================] - 47s 1s/step - loss: 1.6560 - misogynous_loss: 0.3358 - a_loss: 0.2799 - b_loss: 0.4284 - c_loss: 0.3565 - d_loss: 0.2554 - misogynous_accuracy: 0.8528 - a_accuracy: 0.8820 - b_accuracy: 0.7806 - c_accuracy: 0.8492 - d_accuracy: 0.9077 - val_loss: 1.8832 - val_misogynous_loss: 0.4356 - val_a_loss: 0.3231 - val_b_loss: 0.4891 - val_c_loss: 0.3735 - val_d_loss: 0.2618 - val_misogynous_accuracy: 0.8080 - val_a_accuracy: 0.8820 - val_b_accuracy: 0.7400 - val_c_accuracy: 0.8360 - val_d_accuracy: 0.9140
# Epoch 7/50
# 39/39 [==============================] - 47s 1s/step - loss: 1.4690 - misogynous_loss: 0.2636 - a_loss: 0.2644 - b_loss: 0.3870 - c_loss: 0.3211 - d_loss: 0.2329 - misogynous_accuracy: 0.8938 - a_accuracy: 0.8875 - b_accuracy: 0.8061 - c_accuracy: 0.8604 - d_accuracy: 0.9109 - val_loss: 1.7817 - val_misogynous_loss: 0.4085 - val_a_loss: 0.3194 - val_b_loss: 0.4490 - val_c_loss: 0.3635 - val_d_loss: 0.2414 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8780 - val_b_accuracy: 0.7700 - val_c_accuracy: 0.8400 - val_d_accuracy: 0.9020
# Epoch 8/50
# 39/39 [==============================] - 47s 1s/step - loss: 1.2337 - misogynous_loss: 0.2054 - a_loss: 0.2292 - b_loss: 0.3266 - c_loss: 0.2791 - d_loss: 0.1935 - misogynous_accuracy: 0.9197 - a_accuracy: 0.9033 - b_accuracy: 0.8431 - c_accuracy: 0.8719 - d_accuracy: 0.9256 - val_loss: 1.8547 - val_misogynous_loss: 0.4465 - val_a_loss: 0.3060 - val_b_loss: 0.5294 - val_c_loss: 0.3511 - val_d_loss: 0.2218 - val_misogynous_accuracy: 0.8280 - val_a_accuracy: 0.8860 - val_b_accuracy: 0.7580 - val_c_accuracy: 0.8520 - val_d_accuracy: 0.9200
# Epoch 9/50
# 39/39 [==============================] - 47s 1s/step - loss: 1.0202 - misogynous_loss: 0.1323 - a_loss: 0.2087 - b_loss: 0.2960 - c_loss: 0.2271 - d_loss: 0.1562 - misogynous_accuracy: 0.9509 - a_accuracy: 0.9109 - b_accuracy: 0.8632 - c_accuracy: 0.9040 - d_accuracy: 0.9412 - val_loss: 1.8587 - val_misogynous_loss: 0.4624 - val_a_loss: 0.3293 - val_b_loss: 0.4596 - val_c_loss: 0.3867 - val_d_loss: 0.2208 - val_misogynous_accuracy: 0.8140 - val_a_accuracy: 0.8880 - val_b_accuracy: 0.7940 - val_c_accuracy: 0.8560 - val_d_accuracy: 0.9280
# Epoch 10/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.8071 - misogynous_loss: 0.0867 - a_loss: 0.1701 - b_loss: 0.2315 - c_loss: 0.1872 - d_loss: 0.1315 - misogynous_accuracy: 0.9700 - a_accuracy: 0.9284 - b_accuracy: 0.8926 - c_accuracy: 0.9201 - d_accuracy: 0.9507 - val_loss: 1.9740 - val_misogynous_loss: 0.4990 - val_a_loss: 0.3522 - val_b_loss: 0.4756 - val_c_loss: 0.4232 - val_d_loss: 0.2240 - val_misogynous_accuracy: 0.8400 - val_a_accuracy: 0.8760 - val_b_accuracy: 0.8220 - val_c_accuracy: 0.8380 - val_d_accuracy: 0.9280
# Epoch 11/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.6222 - misogynous_loss: 0.0656 - a_loss: 0.1388 - b_loss: 0.1739 - c_loss: 0.1441 - d_loss: 0.0997 - misogynous_accuracy: 0.9790 - a_accuracy: 0.9460 - b_accuracy: 0.9263 - c_accuracy: 0.9433 - d_accuracy: 0.9610 - val_loss: 2.1532 - val_misogynous_loss: 0.5060 - val_a_loss: 0.4005 - val_b_loss: 0.5294 - val_c_loss: 0.4886 - val_d_loss: 0.2287 - val_misogynous_accuracy: 0.8280 - val_a_accuracy: 0.8720 - val_b_accuracy: 0.8000 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9400
# Epoch 12/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.4665 - misogynous_loss: 0.0500 - a_loss: 0.0982 - b_loss: 0.1403 - c_loss: 0.0996 - d_loss: 0.0785 - misogynous_accuracy: 0.9836 - a_accuracy: 0.9650 - b_accuracy: 0.9393 - c_accuracy: 0.9599 - d_accuracy: 0.9709 - val_loss: 2.4292 - val_misogynous_loss: 0.5595 - val_a_loss: 0.4651 - val_b_loss: 0.5952 - val_c_loss: 0.5319 - val_d_loss: 0.2775 - val_misogynous_accuracy: 0.8240 - val_a_accuracy: 0.8520 - val_b_accuracy: 0.8080 - val_c_accuracy: 0.8480 - val_d_accuracy: 0.9200
# Epoch 13/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.3691 - misogynous_loss: 0.0422 - a_loss: 0.0740 - b_loss: 0.1085 - c_loss: 0.0862 - d_loss: 0.0583 - misogynous_accuracy: 0.9860 - a_accuracy: 0.9744 - b_accuracy: 0.9572 - c_accuracy: 0.9676 - d_accuracy: 0.9788 - val_loss: 2.9230 - val_misogynous_loss: 0.6356 - val_a_loss: 0.5694 - val_b_loss: 0.7672 - val_c_loss: 0.6364 - val_d_loss: 0.3144 - val_misogynous_accuracy: 0.8100 - val_a_accuracy: 0.8740 - val_b_accuracy: 0.8080 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9220
# Epoch 14/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.2685 - misogynous_loss: 0.0376 - a_loss: 0.0526 - b_loss: 0.0747 - c_loss: 0.0668 - d_loss: 0.0368 - misogynous_accuracy: 0.9883 - a_accuracy: 0.9805 - b_accuracy: 0.9711 - c_accuracy: 0.9753 - d_accuracy: 0.9881 - val_loss: 2.9305 - val_misogynous_loss: 0.5836 - val_a_loss: 0.6053 - val_b_loss: 0.8042 - val_c_loss: 0.5922 - val_d_loss: 0.3452 - val_misogynous_accuracy: 0.8260 - val_a_accuracy: 0.8720 - val_b_accuracy: 0.8140 - val_c_accuracy: 0.8500 - val_d_accuracy: 0.9280
# Epoch 15/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.1929 - misogynous_loss: 0.0313 - a_loss: 0.0348 - b_loss: 0.0532 - c_loss: 0.0498 - d_loss: 0.0239 - misogynous_accuracy: 0.9889 - a_accuracy: 0.9873 - b_accuracy: 0.9789 - c_accuracy: 0.9858 - d_accuracy: 0.9924 - val_loss: 3.1603 - val_misogynous_loss: 0.6819 - val_a_loss: 0.6492 - val_b_loss: 0.8341 - val_c_loss: 0.6375 - val_d_loss: 0.3577 - val_misogynous_accuracy: 0.8260 - val_a_accuracy: 0.8560 - val_b_accuracy: 0.8080 - val_c_accuracy: 0.8480 - val_d_accuracy: 0.9260
# Epoch 16/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.1767 - misogynous_loss: 0.0304 - a_loss: 0.0317 - b_loss: 0.0461 - c_loss: 0.0426 - d_loss: 0.0259 - misogynous_accuracy: 0.9890 - a_accuracy: 0.9876 - b_accuracy: 0.9817 - c_accuracy: 0.9853 - d_accuracy: 0.9918 - val_loss: 3.4092 - val_misogynous_loss: 0.6928 - val_a_loss: 0.7075 - val_b_loss: 0.8973 - val_c_loss: 0.7323 - val_d_loss: 0.3793 - val_misogynous_accuracy: 0.8380 - val_a_accuracy: 0.8740 - val_b_accuracy: 0.8080 - val_c_accuracy: 0.8380 - val_d_accuracy: 0.9220
# Epoch 17/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.1442 - misogynous_loss: 0.0223 - a_loss: 0.0237 - b_loss: 0.0425 - c_loss: 0.0306 - d_loss: 0.0252 - misogynous_accuracy: 0.9904 - a_accuracy: 0.9933 - b_accuracy: 0.9835 - c_accuracy: 0.9896 - d_accuracy: 0.9897 - val_loss: 3.5584 - val_misogynous_loss: 0.7136 - val_a_loss: 0.6927 - val_b_loss: 0.9039 - val_c_loss: 0.8340 - val_d_loss: 0.4142 - val_misogynous_accuracy: 0.8260 - val_a_accuracy: 0.8680 - val_b_accuracy: 0.8100 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9180
# Epoch 18/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.1277 - misogynous_loss: 0.0210 - a_loss: 0.0222 - b_loss: 0.0316 - c_loss: 0.0363 - d_loss: 0.0166 - misogynous_accuracy: 0.9934 - a_accuracy: 0.9933 - b_accuracy: 0.9894 - c_accuracy: 0.9863 - d_accuracy: 0.9947 - val_loss: 3.6881 - val_misogynous_loss: 0.7183 - val_a_loss: 0.7357 - val_b_loss: 1.0468 - val_c_loss: 0.7703 - val_d_loss: 0.4170 - val_misogynous_accuracy: 0.8240 - val_a_accuracy: 0.8600 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8480 - val_d_accuracy: 0.9240
# Epoch 19/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.1112 - misogynous_loss: 0.0173 - a_loss: 0.0246 - b_loss: 0.0276 - c_loss: 0.0246 - d_loss: 0.0172 - misogynous_accuracy: 0.9947 - a_accuracy: 0.9914 - b_accuracy: 0.9901 - c_accuracy: 0.9906 - d_accuracy: 0.9943 - val_loss: 3.8042 - val_misogynous_loss: 0.7590 - val_a_loss: 0.7821 - val_b_loss: 1.0213 - val_c_loss: 0.7726 - val_d_loss: 0.4691 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8540 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8500 - val_d_accuracy: 0.9120
# Epoch 20/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0955 - misogynous_loss: 0.0182 - a_loss: 0.0181 - b_loss: 0.0217 - c_loss: 0.0216 - d_loss: 0.0158 - misogynous_accuracy: 0.9949 - a_accuracy: 0.9932 - b_accuracy: 0.9932 - c_accuracy: 0.9920 - d_accuracy: 0.9943 - val_loss: 4.0334 - val_misogynous_loss: 0.7663 - val_a_loss: 0.8332 - val_b_loss: 1.1108 - val_c_loss: 0.8530 - val_d_loss: 0.4700 - val_misogynous_accuracy: 0.8260 - val_a_accuracy: 0.8760 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8480 - val_d_accuracy: 0.9160
# Epoch 21/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0726 - misogynous_loss: 0.0126 - a_loss: 0.0138 - b_loss: 0.0187 - c_loss: 0.0162 - d_loss: 0.0112 - misogynous_accuracy: 0.9973 - a_accuracy: 0.9960 - b_accuracy: 0.9931 - c_accuracy: 0.9951 - d_accuracy: 0.9968 - val_loss: 4.1008 - val_misogynous_loss: 0.8472 - val_a_loss: 0.8491 - val_b_loss: 1.0552 - val_c_loss: 0.8566 - val_d_loss: 0.4927 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8560 - val_b_accuracy: 0.7980 - val_c_accuracy: 0.8460 - val_d_accuracy: 0.9260
# Epoch 22/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0611 - misogynous_loss: 0.0095 - a_loss: 0.0132 - b_loss: 0.0138 - c_loss: 0.0132 - d_loss: 0.0114 - misogynous_accuracy: 0.9975 - a_accuracy: 0.9951 - b_accuracy: 0.9952 - c_accuracy: 0.9950 - d_accuracy: 0.9960 - val_loss: 4.1977 - val_misogynous_loss: 0.8660 - val_a_loss: 0.8855 - val_b_loss: 1.0632 - val_c_loss: 0.8948 - val_d_loss: 0.4883 - val_misogynous_accuracy: 0.8320 - val_a_accuracy: 0.8540 - val_b_accuracy: 0.8100 - val_c_accuracy: 0.8580 - val_d_accuracy: 0.9260
# Epoch 23/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0649 - misogynous_loss: 0.0128 - a_loss: 0.0120 - b_loss: 0.0187 - c_loss: 0.0113 - d_loss: 0.0102 - misogynous_accuracy: 0.9955 - a_accuracy: 0.9967 - b_accuracy: 0.9929 - c_accuracy: 0.9966 - d_accuracy: 0.9976 - val_loss: 4.4328 - val_misogynous_loss: 0.8389 - val_a_loss: 0.8996 - val_b_loss: 1.2550 - val_c_loss: 0.9458 - val_d_loss: 0.4935 - val_misogynous_accuracy: 0.8120 - val_a_accuracy: 0.8620 - val_b_accuracy: 0.8060 - val_c_accuracy: 0.8460 - val_d_accuracy: 0.9180
# Epoch 24/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0458 - misogynous_loss: 0.0079 - a_loss: 0.0086 - b_loss: 0.0130 - c_loss: 0.0099 - d_loss: 0.0064 - misogynous_accuracy: 0.9977 - a_accuracy: 0.9973 - b_accuracy: 0.9952 - c_accuracy: 0.9964 - d_accuracy: 0.9976 - val_loss: 4.4682 - val_misogynous_loss: 0.8642 - val_a_loss: 0.9029 - val_b_loss: 1.3046 - val_c_loss: 0.8898 - val_d_loss: 0.5068 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8560 - val_b_accuracy: 0.7980 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9240
# Epoch 25/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0376 - misogynous_loss: 0.0076 - a_loss: 0.0070 - b_loss: 0.0087 - c_loss: 0.0087 - d_loss: 0.0056 - misogynous_accuracy: 0.9976 - a_accuracy: 0.9972 - b_accuracy: 0.9962 - c_accuracy: 0.9972 - d_accuracy: 0.9990 - val_loss: 4.6152 - val_misogynous_loss: 0.8614 - val_a_loss: 0.8873 - val_b_loss: 1.3814 - val_c_loss: 0.9791 - val_d_loss: 0.5060 - val_misogynous_accuracy: 0.8140 - val_a_accuracy: 0.8720 - val_b_accuracy: 0.7820 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9240
# Epoch 26/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0338 - misogynous_loss: 0.0067 - a_loss: 0.0078 - b_loss: 0.0060 - c_loss: 0.0083 - d_loss: 0.0050 - misogynous_accuracy: 0.9985 - a_accuracy: 0.9978 - b_accuracy: 0.9974 - c_accuracy: 0.9973 - d_accuracy: 0.9985 - val_loss: 4.7207 - val_misogynous_loss: 0.9486 - val_a_loss: 0.9101 - val_b_loss: 1.3933 - val_c_loss: 0.9235 - val_d_loss: 0.5451 - val_misogynous_accuracy: 0.8140 - val_a_accuracy: 0.8720 - val_b_accuracy: 0.7940 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9160
# Epoch 27/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0374 - misogynous_loss: 0.0070 - a_loss: 0.0048 - b_loss: 0.0103 - c_loss: 0.0088 - d_loss: 0.0066 - misogynous_accuracy: 0.9978 - a_accuracy: 0.9986 - b_accuracy: 0.9966 - c_accuracy: 0.9968 - d_accuracy: 0.9980 - val_loss: 4.8899 - val_misogynous_loss: 0.8759 - val_a_loss: 0.9477 - val_b_loss: 1.4637 - val_c_loss: 1.0238 - val_d_loss: 0.5787 - val_misogynous_accuracy: 0.8200 - val_a_accuracy: 0.8780 - val_b_accuracy: 0.8040 - val_c_accuracy: 0.8500 - val_d_accuracy: 0.9200
# Epoch 28/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0304 - misogynous_loss: 0.0077 - a_loss: 0.0031 - b_loss: 0.0079 - c_loss: 0.0068 - d_loss: 0.0048 - misogynous_accuracy: 0.9975 - a_accuracy: 0.9994 - b_accuracy: 0.9975 - c_accuracy: 0.9979 - d_accuracy: 0.9987 - val_loss: 4.9306 - val_misogynous_loss: 0.9160 - val_a_loss: 0.9830 - val_b_loss: 1.3896 - val_c_loss: 1.0967 - val_d_loss: 0.5453 - val_misogynous_accuracy: 0.8240 - val_a_accuracy: 0.8600 - val_b_accuracy: 0.7980 - val_c_accuracy: 0.8520 - val_d_accuracy: 0.9220
# Epoch 29/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0290 - misogynous_loss: 0.0074 - a_loss: 0.0027 - b_loss: 0.0061 - c_loss: 0.0073 - d_loss: 0.0055 - misogynous_accuracy: 0.9980 - a_accuracy: 0.9995 - b_accuracy: 0.9986 - c_accuracy: 0.9977 - d_accuracy: 0.9985 - val_loss: 4.9414 - val_misogynous_loss: 0.9381 - val_a_loss: 0.9578 - val_b_loss: 1.4678 - val_c_loss: 1.0263 - val_d_loss: 0.5514 - val_misogynous_accuracy: 0.8400 - val_a_accuracy: 0.8700 - val_b_accuracy: 0.7900 - val_c_accuracy: 0.8500 - val_d_accuracy: 0.9240
# Epoch 30/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0225 - misogynous_loss: 0.0043 - a_loss: 0.0036 - b_loss: 0.0059 - c_loss: 0.0051 - d_loss: 0.0036 - misogynous_accuracy: 0.9990 - a_accuracy: 0.9989 - b_accuracy: 0.9984 - c_accuracy: 0.9990 - d_accuracy: 0.9991 - val_loss: 5.0066 - val_misogynous_loss: 0.9596 - val_a_loss: 1.0092 - val_b_loss: 1.4772 - val_c_loss: 1.0017 - val_d_loss: 0.5588 - val_misogynous_accuracy: 0.8440 - val_a_accuracy: 0.8780 - val_b_accuracy: 0.7840 - val_c_accuracy: 0.8560 - val_d_accuracy: 0.9140
# Epoch 31/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0210 - misogynous_loss: 0.0033 - a_loss: 0.0023 - b_loss: 0.0066 - c_loss: 0.0048 - d_loss: 0.0040 - misogynous_accuracy: 0.9990 - a_accuracy: 0.9996 - b_accuracy: 0.9973 - c_accuracy: 0.9986 - d_accuracy: 0.9990 - val_loss: 5.1997 - val_misogynous_loss: 0.9943 - val_a_loss: 1.0168 - val_b_loss: 1.6046 - val_c_loss: 1.0178 - val_d_loss: 0.5662 - val_misogynous_accuracy: 0.8280 - val_a_accuracy: 0.8760 - val_b_accuracy: 0.7760 - val_c_accuracy: 0.8540 - val_d_accuracy: 0.9240
# Epoch 32/50
# 39/39 [==============================] - 48s 1s/step - loss: 0.0280 - misogynous_loss: 0.0047 - a_loss: 0.0024 - b_loss: 0.0075 - c_loss: 0.0095 - d_loss: 0.0038 - misogynous_accuracy: 0.9987 - a_accuracy: 0.9995 - b_accuracy: 0.9973 - c_accuracy: 0.9968 - d_accuracy: 0.9982 - val_loss: 5.1327 - val_misogynous_loss: 1.0034 - val_a_loss: 1.0402 - val_b_loss: 1.4662 - val_c_loss: 1.0563 - val_d_loss: 0.5665 - val_misogynous_accuracy: 0.8360 - val_a_accuracy: 0.8660 - val_b_accuracy: 0.8140 - val_c_accuracy: 0.8500 - val_d_accuracy: 0.9140
# Epoch 33/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0172 - misogynous_loss: 0.0037 - a_loss: 0.0019 - b_loss: 0.0049 - c_loss: 0.0038 - d_loss: 0.0029 - misogynous_accuracy: 0.9990 - a_accuracy: 0.9991 - b_accuracy: 0.9985 - c_accuracy: 0.9988 - d_accuracy: 0.9991 - val_loss: 5.1829 - val_misogynous_loss: 1.0292 - val_a_loss: 1.0335 - val_b_loss: 1.4775 - val_c_loss: 1.0339 - val_d_loss: 0.6088 - val_misogynous_accuracy: 0.8380 - val_a_accuracy: 0.8760 - val_b_accuracy: 0.8100 - val_c_accuracy: 0.8460 - val_d_accuracy: 0.9160
# Epoch 34/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0209 - misogynous_loss: 0.0040 - a_loss: 0.0039 - b_loss: 0.0061 - c_loss: 0.0047 - d_loss: 0.0022 - misogynous_accuracy: 0.9989 - a_accuracy: 0.9989 - b_accuracy: 0.9973 - c_accuracy: 0.9981 - d_accuracy: 0.9993 - val_loss: 5.2504 - val_misogynous_loss: 0.9816 - val_a_loss: 1.0937 - val_b_loss: 1.4655 - val_c_loss: 1.0900 - val_d_loss: 0.6196 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8700 - val_b_accuracy: 0.8000 - val_c_accuracy: 0.8380 - val_d_accuracy: 0.9220
# Epoch 35/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0185 - misogynous_loss: 0.0033 - a_loss: 0.0033 - b_loss: 0.0057 - c_loss: 0.0029 - d_loss: 0.0034 - misogynous_accuracy: 0.9989 - a_accuracy: 0.9988 - b_accuracy: 0.9979 - c_accuracy: 0.9992 - d_accuracy: 0.9994 - val_loss: 5.3862 - val_misogynous_loss: 1.0322 - val_a_loss: 1.0605 - val_b_loss: 1.5090 - val_c_loss: 1.1521 - val_d_loss: 0.6324 - val_misogynous_accuracy: 0.8340 - val_a_accuracy: 0.8680 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8360 - val_d_accuracy: 0.9100
# Epoch 36/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0265 - misogynous_loss: 0.0039 - a_loss: 0.0036 - b_loss: 0.0095 - c_loss: 0.0069 - d_loss: 0.0025 - misogynous_accuracy: 0.9986 - a_accuracy: 0.9989 - b_accuracy: 0.9974 - c_accuracy: 0.9981 - d_accuracy: 0.9990 - val_loss: 5.4129 - val_misogynous_loss: 0.9822 - val_a_loss: 1.0996 - val_b_loss: 1.5693 - val_c_loss: 1.1093 - val_d_loss: 0.6526 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8660 - val_b_accuracy: 0.8180 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9200
# Epoch 37/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0192 - misogynous_loss: 0.0029 - a_loss: 0.0030 - b_loss: 0.0070 - c_loss: 0.0026 - d_loss: 0.0036 - misogynous_accuracy: 0.9991 - a_accuracy: 0.9988 - b_accuracy: 0.9981 - c_accuracy: 0.9994 - d_accuracy: 0.9984 - val_loss: 5.2652 - val_misogynous_loss: 0.9847 - val_a_loss: 1.0976 - val_b_loss: 1.4572 - val_c_loss: 1.1004 - val_d_loss: 0.6254 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8680 - val_b_accuracy: 0.7980 - val_c_accuracy: 0.8520 - val_d_accuracy: 0.9260
# Epoch 38/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0190 - misogynous_loss: 0.0031 - a_loss: 0.0022 - b_loss: 0.0047 - c_loss: 0.0045 - d_loss: 0.0045 - misogynous_accuracy: 0.9991 - a_accuracy: 0.9994 - b_accuracy: 0.9980 - c_accuracy: 0.9979 - d_accuracy: 0.9982 - val_loss: 5.4485 - val_misogynous_loss: 1.0324 - val_a_loss: 1.1087 - val_b_loss: 1.5037 - val_c_loss: 1.2044 - val_d_loss: 0.5994 - val_misogynous_accuracy: 0.8320 - val_a_accuracy: 0.8640 - val_b_accuracy: 0.8060 - val_c_accuracy: 0.8460 - val_d_accuracy: 0.9220
# Epoch 39/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0209 - misogynous_loss: 0.0042 - a_loss: 0.0025 - b_loss: 0.0051 - c_loss: 0.0049 - d_loss: 0.0043 - misogynous_accuracy: 0.9986 - a_accuracy: 0.9994 - b_accuracy: 0.9985 - c_accuracy: 0.9985 - d_accuracy: 0.9988 - val_loss: 5.4982 - val_misogynous_loss: 1.0625 - val_a_loss: 1.0795 - val_b_loss: 1.6131 - val_c_loss: 1.1484 - val_d_loss: 0.5947 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8660 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8400 - val_d_accuracy: 0.9220
# Epoch 40/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0152 - misogynous_loss: 0.0035 - a_loss: 0.0015 - b_loss: 0.0021 - c_loss: 0.0049 - d_loss: 0.0032 - misogynous_accuracy: 0.9994 - a_accuracy: 0.9995 - b_accuracy: 0.9996 - c_accuracy: 0.9984 - d_accuracy: 0.9990 - val_loss: 5.4917 - val_misogynous_loss: 1.0485 - val_a_loss: 1.1011 - val_b_loss: 1.5680 - val_c_loss: 1.1599 - val_d_loss: 0.6141 - val_misogynous_accuracy: 0.8400 - val_a_accuracy: 0.8740 - val_b_accuracy: 0.8100 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9220
# Epoch 41/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0141 - misogynous_loss: 0.0031 - a_loss: 0.0018 - b_loss: 0.0029 - c_loss: 0.0047 - d_loss: 0.0016 - misogynous_accuracy: 0.9991 - a_accuracy: 0.9998 - b_accuracy: 0.9990 - c_accuracy: 0.9992 - d_accuracy: 0.9996 - val_loss: 5.6004 - val_misogynous_loss: 1.0410 - val_a_loss: 1.0983 - val_b_loss: 1.6315 - val_c_loss: 1.2245 - val_d_loss: 0.6051 - val_misogynous_accuracy: 0.8320 - val_a_accuracy: 0.8620 - val_b_accuracy: 0.8060 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9220
# Epoch 42/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0142 - misogynous_loss: 0.0043 - a_loss: 0.0026 - b_loss: 0.0026 - c_loss: 0.0034 - d_loss: 0.0013 - misogynous_accuracy: 0.9983 - a_accuracy: 0.9988 - b_accuracy: 0.9992 - c_accuracy: 0.9987 - d_accuracy: 0.9998 - val_loss: 5.7289 - val_misogynous_loss: 1.0007 - val_a_loss: 1.1155 - val_b_loss: 1.5966 - val_c_loss: 1.3538 - val_d_loss: 0.6624 - val_misogynous_accuracy: 0.8300 - val_a_accuracy: 0.8640 - val_b_accuracy: 0.8080 - val_c_accuracy: 0.8520 - val_d_accuracy: 0.9220
# Epoch 43/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0156 - misogynous_loss: 0.0028 - a_loss: 0.0017 - b_loss: 0.0023 - c_loss: 0.0073 - d_loss: 0.0016 - misogynous_accuracy: 0.9993 - a_accuracy: 0.9993 - b_accuracy: 0.9990 - c_accuracy: 0.9974 - d_accuracy: 0.9995 - val_loss: 5.7093 - val_misogynous_loss: 0.9878 - val_a_loss: 1.1229 - val_b_loss: 1.6530 - val_c_loss: 1.2997 - val_d_loss: 0.6460 - val_misogynous_accuracy: 0.8340 - val_a_accuracy: 0.8660 - val_b_accuracy: 0.8100 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9200
# Epoch 44/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0135 - misogynous_loss: 0.0032 - a_loss: 0.0030 - b_loss: 0.0021 - c_loss: 0.0026 - d_loss: 0.0027 - misogynous_accuracy: 0.9990 - a_accuracy: 0.9993 - b_accuracy: 0.9997 - c_accuracy: 0.9988 - d_accuracy: 0.9990 - val_loss: 5.6930 - val_misogynous_loss: 0.9684 - val_a_loss: 1.1462 - val_b_loss: 1.5612 - val_c_loss: 1.3714 - val_d_loss: 0.6458 - val_misogynous_accuracy: 0.8320 - val_a_accuracy: 0.8700 - val_b_accuracy: 0.8000 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9200
# Epoch 45/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0139 - misogynous_loss: 0.0017 - a_loss: 0.0023 - b_loss: 0.0019 - c_loss: 0.0064 - d_loss: 0.0017 - misogynous_accuracy: 0.9997 - a_accuracy: 0.9997 - b_accuracy: 0.9997 - c_accuracy: 0.9979 - d_accuracy: 0.9994 - val_loss: 5.6428 - val_misogynous_loss: 1.0028 - val_a_loss: 1.1471 - val_b_loss: 1.6061 - val_c_loss: 1.2253 - val_d_loss: 0.6615 - val_misogynous_accuracy: 0.8380 - val_a_accuracy: 0.8780 - val_b_accuracy: 0.8000 - val_c_accuracy: 0.8480 - val_d_accuracy: 0.9260
# Epoch 46/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0153 - misogynous_loss: 0.0017 - a_loss: 0.0011 - b_loss: 0.0034 - c_loss: 0.0063 - d_loss: 0.0028 - misogynous_accuracy: 0.9998 - a_accuracy: 0.9998 - b_accuracy: 0.9990 - c_accuracy: 0.9985 - d_accuracy: 0.9992 - val_loss: 5.6235 - val_misogynous_loss: 1.0069 - val_a_loss: 1.1240 - val_b_loss: 1.6140 - val_c_loss: 1.2190 - val_d_loss: 0.6596 - val_misogynous_accuracy: 0.8460 - val_a_accuracy: 0.8800 - val_b_accuracy: 0.7980 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9160
# Epoch 47/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0111 - misogynous_loss: 0.0015 - a_loss: 8.7413e-04 - b_loss: 0.0023 - c_loss: 0.0051 - d_loss: 0.0014 - misogynous_accuracy: 0.9997 - a_accuracy: 0.9998 - b_accuracy: 0.9994 - c_accuracy: 0.9984 - d_accuracy: 0.9995 - val_loss: 5.7721 - val_misogynous_loss: 1.0992 - val_a_loss: 1.1335 - val_b_loss: 1.6619 - val_c_loss: 1.2180 - val_d_loss: 0.6595 - val_misogynous_accuracy: 0.8380 - val_a_accuracy: 0.8780 - val_b_accuracy: 0.8000 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9180
# Epoch 48/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0139 - misogynous_loss: 0.0022 - a_loss: 0.0049 - b_loss: 0.0027 - c_loss: 0.0024 - d_loss: 0.0018 - misogynous_accuracy: 0.9993 - a_accuracy: 0.9988 - b_accuracy: 0.9987 - c_accuracy: 0.9990 - d_accuracy: 0.9992 - val_loss: 5.8443 - val_misogynous_loss: 1.1086 - val_a_loss: 1.1068 - val_b_loss: 1.7009 - val_c_loss: 1.2625 - val_d_loss: 0.6656 - val_misogynous_accuracy: 0.8400 - val_a_accuracy: 0.8700 - val_b_accuracy: 0.7940 - val_c_accuracy: 0.8420 - val_d_accuracy: 0.9200
# Epoch 49/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0079 - misogynous_loss: 0.0014 - a_loss: 9.8799e-04 - b_loss: 0.0025 - c_loss: 0.0020 - d_loss: 0.0011 - misogynous_accuracy: 0.9995 - a_accuracy: 0.9999 - b_accuracy: 0.9988 - c_accuracy: 0.9993 - d_accuracy: 0.9997 - val_loss: 5.8885 - val_misogynous_loss: 1.1354 - val_a_loss: 1.1239 - val_b_loss: 1.7323 - val_c_loss: 1.2078 - val_d_loss: 0.6891 - val_misogynous_accuracy: 0.8400 - val_a_accuracy: 0.8740 - val_b_accuracy: 0.8020 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9220
# Epoch 50/50
# 39/39 [==============================] - 47s 1s/step - loss: 0.0075 - misogynous_loss: 0.0014 - a_loss: 0.0012 - b_loss: 0.0018 - c_loss: 0.0018 - d_loss: 0.0014 - misogynous_accuracy: 0.9997 - a_accuracy: 0.9996 - b_accuracy: 0.9992 - c_accuracy: 0.9997 - d_accuracy: 0.9996 - val_loss: 5.9209 - val_misogynous_loss: 1.0779 - val_a_loss: 1.1829 - val_b_loss: 1.6925 - val_c_loss: 1.2786 - val_d_loss: 0.6890 - val_misogynous_accuracy: 0.8500 - val_a_accuracy: 0.8720 - val_b_accuracy: 0.8180 - val_c_accuracy: 0.8440 - val_d_accuracy: 0.9180

# %%
model_dir = "./MAMI_Bert_5_output"
# !rm -r {model_dir}
# !mkdir {model_dir}

localhost_save_option = tf.saved_model.SaveOptions(experimental_io_device="/job:localhost")
model.save(model_dir, options=localhost_save_option)
# Out:
# rm: cannot remove './MAMI_Bert_5_output': No such file or directory
# 2022-01-27 09:47:22.107708: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.

# %%
with open(f'./{model_dir}/model.txt', 'w') as file:
    file.write('''def create_model(maxlen=512):
    text_model = TFBertModel.from_pretrained("bert-base-uncased")
    image_model = tf.keras.applications.efficientnet.EfficientNetB5(
          include_top=False,
          input_shape=(299, 299, 3)
    )
    for layer in image_model.layers[:-25]:
        layer.trainable = False
    x = tf.keras.layers.GlobalAveragePooling2D()(image_model.output)
    x = tf.keras.layers.Dense(2048,activation='relu')(x) # Best model has this
  
    input_ids = tf.keras.Input(shape=(maxlen,),dtype='int32', name='input_text')
    sequence_output = text_model(input_ids)[0]
    cls_token = sequence_output[:, 0, :]
    cls_token = tf.keras.layers.Dense(2048,activation='relu')(cls_token) # Best model has this
  
    concat_layer = tf.keras.layers.Concatenate()([x, cls_token])
  
    output = tf.keras.layers.Dense(512,activation='relu')(concat_layer)
    output = tf.keras.layers.Dropout(0.2)(output) # Best model has this
    binary_output = tf.keras.layers.Dense(1,activation='sigmoid', name='misogynous')(output)
    multi_label_output = tf.keras.layers.Dense(512,activation='relu')(output) # Best model has this
    a = tf.keras.layers.Dense(1,activation='sigmoid', name='a')(multi_label_output) # Best model has this
    b = tf.keras.layers.Dense(128,activation='relu')(multi_label_output) # Best model has this
    b = tf.keras.layers.Dense(1,activation='sigmoid', name='b')(b) # Best model has this
    c = tf.keras.layers.Dense(1,activation='sigmoid', name='c')(multi_label_output) # Best model has this
    d = tf.keras.layers.Dense(1,activation='sigmoid', name='d')(multi_label_output) # Best model has this
    model = tf.keras.models.Model(inputs = [image_model.input, input_ids], outputs=[binary_output, a, b, c, d])
    model.compile(tf.keras.optimizers.Adam(learning_rate=6e-5), loss={'misogynous': 'binary_crossentropy', 'a': 'binary_crossentropy', 'b': 'binary_crossentropy', 'c': 'binary_crossentropy', 'd': 'binary_crossentropy'}, metrics=['accuracy'])
    return model''')

# %%
# !zip -r "./MAMI_Bert_5_output_eff_8460.zip" "./MAMI_Bert_5_output"
# Out:
#   adding: MAMI_Bert_5_output/ (stored 0%)
#   adding: MAMI_Bert_5_output/saved_model.pb (deflated 92%)
#   adding: MAMI_Bert_5_output/variables/ (stored 0%)
#   adding: MAMI_Bert_5_output/variables/variables.index (deflated 80%)
#   adding: MAMI_Bert_5_output/variables/variables.data-00000-of-00001 (deflated 14%)
#   adding: MAMI_Bert_5_output/assets/ (stored 0%)
#   adding: MAMI_Bert_5_output/model.txt (deflated 68%)

# %%
# !rm -r "./MAMI_Bert_5_output"
